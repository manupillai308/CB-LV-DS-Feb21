# %%
import warnings 
warnings.filterwarnings("ignore")

# %%
from keras.layers import Dense
from keras.models import Sequential
# from keras.activations import sigmoid
# from keras.losses import binary_crossentropy
from keras.metrics import binary_accuracy
from keras.optimizers import SGD

# %%
model = Sequential()
model.add(Dense(3, activation="relu", input_shape=(2,)))
model.add(Dense(2, activation="relu"))
model.add(Dense(1, activation="sigmoid"))

# %%
model.compile(optimizer=SGD(lr=0.1), loss="binary_crossentropy", metrics=["accuracy"])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_10 (Dense)             (None, 3)                 9
# _________________________________________________________________
# dense_11 (Dense)             (None, 2)                 8
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 3
# ...
# Total params: 20
# Trainable params: 20
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.datasets import make_gaussian_quantiles

X, y = make_gaussian_quantiles(n_features=2, n_classes=2, n_samples=500)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.show()

# %%
model.fit(X, y, batch_size=500, epochs=200, verbose=1)
# Out:
# Epoch 1/200
# 500/500 [==============================] - 0s 12us/step - loss: 0.1302 - acc: 0.9740
# Epoch 2/200
# 500/500 [==============================] - 0s 18us/step - loss: 0.1300 - acc: 0.9740
# Epoch 3/200
# 500/500 [==============================] - 0s 18us/step - loss: 0.1298 - acc: 0.9740
# Epoch 4/200
# 500/500 [==============================] - 0s 6us/step - loss: 0.1296 - acc: 0.9740
# Epoch 5/200
# 500/500 [==============================] - 0s 6us/step - loss: 0.1294 - acc: 0.9740
# Epoch 6/200
# 500/500 [==============================] - 0s 14us/step - loss: 0.1292 - acc: 0.9740
# Epoch 7/200
# 500/500 [==============================] - 0s 12us/step - loss: 0.1291 - acc: 0.9740
# Epoch 8/200
# 500/500 [==============================] - 0s 11us/step - loss: 0.1289 - acc: 0.9740
# Epoch 9/200
# 500/500 [==============================] - 0s 17us/step - loss: 0.1287 - acc: 0.9740
# Epoch 10/200
# ...

# %%
model.evaluate(X, y)
# Out:
# 500/500 [==============================] - 0s 382us/step
# [0.10355897659063339, 0.9799999995231629]

# %%
from keras.models import Model

model1 = Model(inputs=[model.input], outputs=[model.get_layer("dense_11").output])

X1 = model1.predict(X)

# %%
X1.shape
# Out:
# (500, 2)

# %%
plt.scatter(X1[:, 0], X1[:, 1], c=y)
plt.show()
